# %%
import pandas as pd

# %%
df=pd.read_csv('employees.csv')

# %%
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %%
g=df.groupby(['DEPARTMENT_ID','FIRST_NAME'])

# %%
g['DEPARTMENT_ID'].count()
# Out:
# DEPARTMENT_ID  FIRST_NAME
# 10             Jennifer       1
# 20             Michael        1
#                Pat            1
# 30             Alexander      1
#                Den            1
#                Guy            1
#                Karen          1
#                Shelli         1
#                Sigal          1
# 40             Susan          1
# 50             Adam           1
#                Donald         1
#                Douglas        1
#                Hazel          1
#                Irene          1
#                James          2
#                Jason          1
#                John           1
#                Joshua         1
#                Julia          1
#                Kevin          1
#                Ki             1
#                Laura          1
#                Matthew        1
#                Michael        1
#                Mozhe          1
#                Payam          1
#                Renske         1
# ...

# %%
g['EMPLOYEE_ID'].count()
# Out:
# DEPARTMENT_ID  FIRST_NAME
# 10             Jennifer       1
# 20             Michael        1
#                Pat            1
# 30             Alexander      1
#                Den            1
#                Guy            1
#                Karen          1
#                Shelli         1
#                Sigal          1
# 40             Susan          1
# 50             Adam           1
#                Donald         1
#                Douglas        1
#                Hazel          1
#                Irene          1
#                James          2
#                Jason          1
#                John           1
#                Joshua         1
#                Julia          1
#                Kevin          1
#                Ki             1
#                Laura          1
#                Matthew        1
#                Michael        1
#                Mozhe          1
#                Payam          1
#                Renske         1
# ...

# %%
print(g.groups)
# Out:
# {(10, 'Jennifer'): RangeIndex(start=2, stop=3, step=1), (20, 'Michael'): RangeIndex(start=3, stop=4, step=1), (20, 'Pat'): RangeIndex(start=4, stop=5, step=1), (30, 'Alexander'): RangeIndex(start=24, stop=25, step=1), (30, 'Den'): RangeIndex(start=23, stop=24, step=1), (30, 'Guy'): RangeIndex(start=27, stop=28, step=1), (30, 'Karen'): RangeIndex(start=28, stop=29, step=1), (30, 'Shelli'): RangeIndex(start=25, stop=26, step=1), (30, 'Sigal'): RangeIndex(start=26, stop=27, step=1), (40, 'Susan'): RangeIndex(start=5, stop=6, step=1), (50, 'Adam'): RangeIndex(start=30, stop=31, step=1), (50, 'Donald'): RangeIndex(start=0, stop=1, step=1), (50, 'Douglas'): RangeIndex(start=1, stop=2, step=1), (50, 'Hazel'): RangeIndex(start=45, stop=46, step=1), (50, 'Irene'): RangeIndex(start=35, stop=36, step=1), (50, 'James'): RangeIndex(start=36, stop=44, step=4), (50, 'Jason'): RangeIndex(start=42, stop=43, step=1), (50, 'John'): RangeIndex(start=48, stop=49, step=1), (50, 'Joshua'): RangeIndex(start
# ...

# %%
g.first()
# Out:
#                            EMPLOYEE_ID    LAST_NAME     EMAIL  PHONE_NUMBER  \
# DEPARTMENT_ID FIRST_NAME
# 10            Jennifer             200       Whalen   JWHALEN  515.123.4444
# 20            Michael              201    Hartstein  MHARTSTE  515.123.5555
#               Pat                  202          Fay      PFAY  603.123.6666
# 30            Alexander            115         Khoo     AKHOO  515.127.4562
#               Den                  114     Raphaely  DRAPHEAL  515.127.4561
#               Guy                  118       Himuro   GHIMURO  515.127.4565
#               Karen                119   Colmenares  KCOLMENA  515.127.4566
#               Shelli               116        Baida    SBAIDA  515.127.4563
#               Sigal                117       Tobias   STOBIAS  515.127.4564
# 40            Susan                203       Mavris   SMAVRIS  515.123.7777
# 50            Adam                 121        Fripp    AFRIPP  650.123.2234
# ...

# %%
for group in g:
    print(group)
# Out:
# ((10, 'Jennifer'),    EMPLOYEE_ID FIRST_NAME LAST_NAME    EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 2          200   Jennifer    Whalen  JWHALEN  515.123.4444  17-SEP-03
#
#     JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 2  AD_ASST    4400             -         101             10  )
# ((20, 'Michael'),    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
#
#    JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 3  MK_MAN   13000             -         100             20  )
# ((20, 'Pat'),    EMPLOYEE_ID FIRST_NAME LAST_NAME EMAIL  PHONE_NUMBER  HIRE_DATE  JOB_ID  \
# 4          202        Pat       Fay  PFAY  603.123.6666  17-AUG-05  MK_REP
#
#    SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 4    6000             -         201             20  )
# ((30, 'Alexander'),     EMPLOYEE_ID FIRST_NAME LAST_NAME  EMAIL  PHONE_NUMBER  HIRE_DATE  \
# ...

# %%
print(g.groups)
# Out:
# {(10, 'Jennifer'): RangeIndex(start=2, stop=3, step=1), (20, 'Michael'): RangeIndex(start=3, stop=4, step=1), (20, 'Pat'): RangeIndex(start=4, stop=5, step=1), (30, 'Alexander'): RangeIndex(start=24, stop=25, step=1), (30, 'Den'): RangeIndex(start=23, stop=24, step=1), (30, 'Guy'): RangeIndex(start=27, stop=28, step=1), (30, 'Karen'): RangeIndex(start=28, stop=29, step=1), (30, 'Shelli'): RangeIndex(start=25, stop=26, step=1), (30, 'Sigal'): RangeIndex(start=26, stop=27, step=1), (40, 'Susan'): RangeIndex(start=5, stop=6, step=1), (50, 'Adam'): RangeIndex(start=30, stop=31, step=1), (50, 'Donald'): RangeIndex(start=0, stop=1, step=1), (50, 'Douglas'): RangeIndex(start=1, stop=2, step=1), (50, 'Hazel'): RangeIndex(start=45, stop=46, step=1), (50, 'Irene'): RangeIndex(start=35, stop=36, step=1), (50, 'James'): RangeIndex(start=36, stop=44, step=4), (50, 'Jason'): RangeIndex(start=42, stop=43, step=1), (50, 'John'): RangeIndex(start=48, stop=49, step=1), (50, 'Joshua'): RangeIndex(start
# ...

# %%
list=['venkat',1,3,4]

# %%
list.append(5)

# %%
list.pop()
# Out:
# 5

# %%
list.extend([2,3,4,6])

# %%
list.remove(3)

# %%
list
# Out:
# ['venkat', 1, 2, 3, 6, 2, 3, 4, 6]

# %%
list.remove(3)

# %%
list
# Out:
# ['venkat', 1, 2, 6, 2, 4, 6]

# %%
list.remove(4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 list.remove(4)
#
# ValueError: list.remove(x): x not in list

# %%
list
# Out:
# ['venkat', 1, 2, 6, 2, 6]

# %%
list.insert(2,9)

# %%
list
# Out:
# ['venkat', 1, 9, 9, 2, 6, 2, 6]

# %%
list.insert(0,3)

# %%
list
# Out:
# [3, 3, 'venkat', 1, 9, 9, 2, 6, 2, 6]

# %%
list[2:2]=['pallavi','pushpa']

# %%
list
# Out:
# [3, 3, 'pallavi', 'pushpa', 'pallavi', 'pushpa', 'venkat', 1, 9, 9, 2, 6, 2, 6]

# %%
del list[4]

# %%
list
# Out:
# [3, 3, 'pallavi', 'pushpa', 1, 9, 9, 2, 6, 2, 6]

# %%
del list[:]

# %%
list
# Out:
# []

# %%
list
# Out:
# []

# %%
list.extend([1,2,3,4,5,6])

# %%
list
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]

# %%
list.clear()

# %%
list
# Out:
# []

# %%
del list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 del list
#
# NameError: name 'list' is not defined

# %%
list
# Out:
# list

# %%
list=[1,2,3,4]

# %%
list
# Out:
# [1, 2, 3, 4]

# %%
list1=list[0:3]

# %%
list1
# Out:
# [1, 2, 3]

# %%
list1[3:]
# Out:
# []
